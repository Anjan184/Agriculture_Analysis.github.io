# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#Load data
df=pd.read_csv("D:\Agri.csv")

# %%
df
# Out:
#                     State        District      Market              Commodity  \
# 0     Andaman and Nicobar   South Andaman  Port Blair             Amaranthus
# 1     Andaman and Nicobar   South Andaman  Port Blair         Banana - Green
# 2     Andaman and Nicobar   South Andaman  Port Blair  Bhindi(Ladies Finger)
# 3     Andaman and Nicobar   South Andaman  Port Blair           Bitter gourd
# 4     Andaman and Nicobar   South Andaman  Port Blair           Black pepper
# ...                   ...             ...         ...                    ...
# 2233          West Bengal  Uttar Dinajpur    Islampur                 Potato
# 2234          West Bengal  Uttar Dinajpur    Islampur                   Rice
# 2235          West Bengal  Uttar Dinajpur     Raiganj                   Jute
# 2236          West Bengal  Uttar Dinajpur     Raiganj                   Rice
# 2237          West Bengal  Uttar Dinajpur     Raiganj                  Wheat
#
# ...

# %%
#Get rows and columns of data
df.shape
# Out:
# (2238, 9)

# %%
#Get first 5 rows of every column
df.head()
# Out:
#                  State       District      Market              Commodity  \
# 0  Andaman and Nicobar  South Andaman  Port Blair             Amaranthus
# 1  Andaman and Nicobar  South Andaman  Port Blair         Banana - Green
# 2  Andaman and Nicobar  South Andaman  Port Blair  Bhindi(Ladies Finger)
# 3  Andaman and Nicobar  South Andaman  Port Blair           Bitter gourd
# 4  Andaman and Nicobar  South Andaman  Port Blair           Black pepper
#
#           Variety Arrival date  Main price  Max price  Modal price
# 0      Amaranthus     3/4/2019        6000       8000         7000
# 1  Banana - Green     3/4/2019        4500       5500         5000
# 2          Bhindi     3/4/2019        6000       8000         7000
# 3           Other     3/4/2019        6000       8000         7000
# 4           Other     3/4/2019      110000     130000       120000

# %%
#Get Datatype and column names
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2238 entries, 0 to 2237
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         2238 non-null   object
#  1   District      2238 non-null   object
#  2   Market        2238 non-null   object
#  3   Commodity     2238 non-null   object
#  4   Variety       2238 non-null   object
#  5   Arrival date  2238 non-null   object
#  6   Main price    2238 non-null   int64
#  7   Max price     2238 non-null   int64
#  8   Modal price   2238 non-null   int64
# dtypes: int64(3), object(6)
# memory usage: 157.5+ KB

# %%
#Get numerical values of every columns
df.describe()
# Out:
#           Main price      Max price    Modal price
# count    2238.000000    2238.000000    2238.000000
# mean     2456.230563    2855.890527    2698.865952
# std      3452.497680    3917.251520    3694.830905
# min         0.000000       0.000000       2.000000
# 25%       800.000000    1000.000000     950.000000
# 50%      1700.000000    1960.000000    1831.500000
# 75%      3200.000000    3700.000000    3500.000000
# max    110000.000000  130000.000000  120000.000000

# %%
#Check whether null value is there or not
df.isnull().sum()
# Out:
# State           0
# District        0
# Market          0
# Commodity       0
# Variety         0
# Arrival date    0
# Main price      0
# Max price       0
# Modal price     0
# dtype: int64

# %%
#Change datatype
df['Arrival date']=pd.to_datetime(df['Arrival date'])

# %%
#Get information about datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2238 entries, 0 to 2237
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         2238 non-null   object
#  1   District      2238 non-null   object
#  2   Market        2238 non-null   object
#  3   Commodity     2238 non-null   object
#  4   Variety       2238 non-null   object
#  5   Arrival date  2238 non-null   object
#  6   Main price    2238 non-null   int64
#  7   Max price     2238 non-null   int64
#  8   Modal price   2238 non-null   int64
# dtypes: int64(3), object(6)
# memory usage: 157.5+ KB

# %%
#Change datatype
df['Main price']=df['Main price'].astype(float)
df['Max price']=df['Max price'].astype(float)
df['Modal price']=df['Modal price'].astype(float)
df['Arrival date']=pd.to_datetime(df['Arrival date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2238 entries, 0 to 2237
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         2238 non-null   object
#  1   District      2238 non-null   object
#  2   Market        2238 non-null   object
#  3   Commodity     2238 non-null   object
#  4   Variety       2238 non-null   object
#  5   Arrival date  2238 non-null   datetime64[ns]
#  6   Main price    2238 non-null   float64
#  7   Max price     2238 non-null   float64
#  8   Modal price   2238 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 157.5+ KB

# %%
#Use of groupby function
df.groupby('Variety')['Modal price'].sum().sort_values(ascending=True).head(10)
# Out:
# Variety
# White Pumpkin     310.0
#  Subabul          440.0
# Plum              570.0
# (Red Nanital)     600.0
# Chips             650.0
# Jalander          750.0
# Beete (Rose)      940.0
# Badshah           946.0
# F.A.Q.           1030.0
# Broken Rice      1200.0
# Name: Modal price, dtype: float64

# %%
plt.scatter(x=df['Variety'],y=df['Modal price'])
plt.title("Price by Variety")
plt.show()

# %%
fig=px.bar(df,x='Commodity',y='Main price')
fig.show()
